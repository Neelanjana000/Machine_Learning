# %% [markdown]
# <a href="https://colab.research.google.com/github/Neelanjana000/Machine_Learning/blob/main/Pandas_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Pandas**

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Dataset/movies.csv')
print(df)
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
print(df.head())
# Out:
#                                  Film    Genre            Lead Studio  \
# 0          Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                     Youth in Revolt   Comedy  The Weinstein Company
# 2  You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                        When in Rome   Comedy                 Disney
# 4               What Happens in Vegas   Comedy                    Fox
#
#    Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 0                70       1.747542                 64         $41.94   2008
# 1                52       1.090000                 68         $19.62   2010
# 2                35       1.211818                 43         $26.66   2010
# 3                44       0.000000                 15         $43.04   2010
# 4                72       6.267647                 28        $219.37   2008

# %%
print(df.head(7))
# Out:
#                                  Film      Genre            Lead Studio  \
# 0          Zack and Miri Make a Porno    Romance  The Weinstein Company
# 1                     Youth in Revolt     Comedy  The Weinstein Company
# 2  You Will Meet a Tall Dark Stranger     Comedy            Independent
# 3                        When in Rome     Comedy                 Disney
# 4               What Happens in Vegas     Comedy                    Fox
# 5                 Water For Elephants      Drama       20th Century Fox
# 6                              WALL-E  Animation                 Disney
#
#    Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 0                70       1.747542                 64         $41.94   2008
# 1                52       1.090000                 68         $19.62   2010
# 2                35       1.211818                 43         $26.66   2010
# 3                44       0.000000                 15         $43.04   2010
# ...

# %%
print(df.tail())
# Out:
#                     Film    Genre  Lead Studio  Audience score %  \
# 72   Across the Universe  romance  Independent                84
# 73         A Serious Man    Drama    Universal                64
# 74    A Dangerous Method    Drama  Independent                89
# 75            27 Dresses   Comedy          Fox                71
# 76  (500) Days of Summer   comedy          Fox                81
#
#     Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 72       0.652603                 54         $29.37   2007
# 73       4.382857                 89         $30.68   2009
# 74       0.448645                 79          $8.97   2011
# 75       5.343622                 40        $160.31   2008
# 76       8.096000                 87         $60.72   2009

# %%
print(df.sample(4))
# Out:
#                          Film      Genre   Lead Studio  Audience score %  \
# 71                  Beginners     Comedy   Independent                80
# 65          Gnomeo and Juliet  Animation        Disney                52
# 59  I Love You Phillip Morris     Comedy   Independent                57
# 40           Music and Lyrics    Romance  Warner Bros.                70
#
#     Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 71       4.471875                 84         $14.31   2011
# 65       5.387972                 56        $193.97   2011
# 59       1.340000                 71         $20.10   2010
# 40       3.647411                 63        $145.90   2007

# %%
print(df[2:6])
# Out:
#                                  Film   Genre       Lead Studio  \
# 2  You Will Meet a Tall Dark Stranger  Comedy       Independent
# 3                        When in Rome  Comedy            Disney
# 4               What Happens in Vegas  Comedy               Fox
# 5                 Water For Elephants   Drama  20th Century Fox
#
#    Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 2                35       1.211818                 43         $26.66   2010
# 3                44       0.000000                 15         $43.04   2010
# 4                72       6.267647                 28        $219.37   2008
# 5                72       3.081421                 60        $117.09   2011

# %%
print(df.shape)
# Out:
# (77, 8)

# %%
df.Profitability
# Out:
# 0     1.747542
# 1     1.090000
# 2     1.211818
# 3     0.000000
# 4     6.267647
#         ...
# 72    0.652603
# 73    4.382857
# 74    0.448645
# 75    5.343622
# 76    8.096000
# Name: Profitability, Length: 77, dtype: float64

# %%
df['Audience score %']
# Out:
# 0     70
# 1     52
# 2     35
# 3     44
# 4     72
#       ..
# 72    84
# 73    64
# 74    89
# 75    71
# 76    81
# Name: Audience score %, Length: 77, dtype: int64

# %%
type(df['Audience score %'])
# Out:
# pandas.core.series.Series

# %%
df['Audience score %'].min(),df['Audience score %'].max(),df['Audience score %'].mean()
# Out:
# (35, 89, 63.72727272727273)

# %%
df_r=df[df.Genre=="Romance"]
df_c=df[df.Genre=="Comedy"]
df_c
# Out:
#                                   Film   Genre            Lead Studio  \
# 1                      Youth in Revolt  Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger  Comedy            Independent
# 3                         When in Rome  Comedy                 Disney
# 4                What Happens in Vegas  Comedy                    Fox
# 9                      Valentine's Day  Comedy           Warner Bros.
# 13                      The Ugly Truth  Comedy            Independent
# 16                        The Proposal  Comedy                 Disney
# 17              The Invention of Lying  Comedy           Warner Bros.
# 18                  The Heartbreak Kid  Comedy              Paramount
# 21                    The Back-up Plan  Comedy                    CBS
# 24              She's Out of My League  Comedy              Paramount
# 25                Sex and the City Two  Comedy           Warner Bros.
# ...

# %%
df_r
# Out:
#                                    Film    Genre            Lead Studio  \
# 0            Zack and Miri Make a Porno  Romance  The Weinstein Company
# 7                              Waitress  Romance            Independent
# 8                   Waiting For Forever  Romance            Independent
# 10  Tyler Perry's Why Did I get Married  Romance            Independent
# 11              Twilight: Breaking Dawn  Romance            Independent
# 12                             Twilight  Romance                 Summit
# 23                   Something Borrowed  Romance            Independent
# 31                      P.S. I Love You  Romance            Independent
# 34                              One Day  Romance            Independent
# 38                       New Year's Eve  Romance           Warner Bros.
# 40                     Music and Lyrics  Romance           Warner Bros.
# 41                          Monte Carlo  Romance       20th Century Fox
# ...

# %%
df_r['Audience score %'].min(),df_r['Audience score %'].max(),df_r['Audience score %'].mean()
# Out:
# (47, 82, 62.76923076923077)

# %%
df_c['Audience score %'].min(),df_c['Audience score %'].max(),df_c['Audience score %'].mean()
# Out:
# (35, 83, 60.97560975609756)

# %% [markdown]
# ##Data Frame Basics

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'Lead Studio', 'Audience score %', 'Profitability',
#        'Rotten Tomatoes %', 'Worldwide Gross', 'Year'],
#       dtype='object')

# %%
df.Genre.unique()
# Out:
# array(['Romance', 'Comedy', 'Drama', 'Animation', 'Fantasy', 'Romence',
#        'Comdy', 'Action', 'romance', 'comedy'], dtype=object)

# %%
df['Lead Studio'].unique()
# Out:
# array(['The Weinstein Company', 'Independent', 'Disney', 'Fox',
#        '20th Century Fox', 'Warner Bros.', 'Summit', 'Paramount', 'CBS',
#        'New Line', 'Sony', 'Universal', 'Lionsgate'], dtype=object)

# %%
df.Genre.value_counts()
# Out:
# Genre
# Comedy       41
# Romance      13
# Drama        13
# Animation     4
# Fantasy       1
# Romence       1
# Comdy         1
# Action        1
# romance       1
# comedy        1
# Name: count, dtype: int64

# %%
df_new=df[["Film","Genre","Year"]]
df_new
# Out:
#                                   Film    Genre  Year
# 0           Zack and Miri Make a Porno  Romance  2008
# 1                      Youth in Revolt   Comedy  2010
# 2   You Will Meet a Tall Dark Stranger   Comedy  2010
# 3                         When in Rome   Comedy  2010
# 4                What Happens in Vegas   Comedy  2008
# ..                                 ...      ...   ...
# 72                 Across the Universe  romance  2007
# 73                       A Serious Man    Drama  2009
# 74                  A Dangerous Method    Drama  2011
# 75                          27 Dresses   Comedy  2008
# 76                (500) Days of Summer   comedy  2009
#
# [77 rows x 3 columns]

# %%
df[(df.Year>=2000)&(df.Year<=2020)]
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
df.describe()

# %%
df.describe()
# Out:
#        Audience score %  Profitability  Rotten Tomatoes %         Year
# count         77.000000      77.000000          77.000000    77.000000
# mean          63.727273       4.599483          46.701299  2009.077922
# std           13.657113       8.031990          26.095001     1.354974
# min           35.000000       0.000000           3.000000  2007.000000
# 25%           52.000000       1.751351          26.000000  2008.000000
# 50%           64.000000       2.642353          45.000000  2009.000000
# 75%           76.000000       5.103117          64.000000  2010.000000
# max           89.000000      66.934000          96.000000  2011.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Film               77 non-null     object
#  1   Genre              77 non-null     object
#  2   Lead Studio        77 non-null     object
#  3   Audience score %   77 non-null     int64
#  4   Profitability      77 non-null     float64
#  5   Rotten Tomatoes %  77 non-null     int64
#  6   Worldwide Gross    77 non-null     object
#  7   Year               77 non-null     int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 4.9+ KB

# %%
df[(df.Profitability==df.Profitability.max())|(df.Profitability==df.Profitability.min())]
# Out:
#                   Film    Genre  Lead Studio  Audience score %  Profitability  \
# 3         When in Rome   Comedy       Disney                44          0.000
# 33  Our Family Wedding   Comedy  Independent                49          0.000
# 57           Jane Eyre  Romance    Universal                77          0.000
# 68           Fireproof    Drama  Independent                51         66.934
#
#     Rotten Tomatoes % Worldwide Gross  Year
# 3                  15         $43.04   2010
# 33                 14         $21.37   2010
# 57                 85         $30.15   2011
# 68                 40         $33.47   2008

# %%
df["Age"]=df['Year'].apply(lambda x:2024-x)
df
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year  \
# ...

# %%
df['Good_Score']=df.apply(lambda x:x['Audience score %']-x['Rotten Tomatoes %'],axis=1)
df
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
# 76                (500) Days of Summer   comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year  \
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=77, step=1)

# %%
df.set_index('Film',inplace=True)
df.head(3)
# Out:
#                                       Genre            Lead Studio  \
# Film
# Zack and Miri Make a Porno          Romance  The Weinstein Company
# Youth in Revolt                      Comedy  The Weinstein Company
# You Will Meet a Tall Dark Stranger   Comedy            Independent
#
#                                     Audience score %  Profitability  \
# Film
# Zack and Miri Make a Porno                        70       1.747542
# Youth in Revolt                                   52       1.090000
# You Will Meet a Tall Dark Stranger                35       1.211818
#
#                                     Rotten Tomatoes % Worldwide Gross  Year  \
# Film
# Zack and Miri Make a Porno                         64         $41.94   2008
# Youth in Revolt                                    68         $19.62   2010
# You Will Meet a Tall Dark Stranger                 43         $26.66   2010
#
#                                     Age  Good_Score
# Film
# ...

# %%
df.index
# Out:
# Index(['Zack and Miri Make a Porno', 'Youth in Revolt',
#        'You Will Meet a Tall Dark Stranger', 'When in Rome',
#        'What Happens in Vegas', 'Water For Elephants', 'WALL-E', 'Waitress',
#        'Waiting For Forever', 'Valentine's Day',
#        'Tyler Perry's Why Did I get Married', 'Twilight: Breaking Dawn',
#        'Twilight', 'The Ugly Truth', 'The Twilight Saga: New Moon',
#        'The Time Traveler's Wife', 'The Proposal', 'The Invention of Lying',
#        'The Heartbreak Kid', 'The Duchess',
#        'The Curious Case of Benjamin Button', 'The Back-up Plan', 'Tangled',
#        'Something Borrowed', 'She's Out of My League', 'Sex and the City Two',
#        'Sex and the City 2', 'Sex and the City', 'Remember Me',
#        'Rachel Getting Married', 'Penelope', 'P.S. I Love You',
#        'Over Her Dead Body', 'Our Family Wedding', 'One Day',
#        'Not Easily Broken', 'No Reservations',
#        'Nick and Norah's Infinite Playlist', 'New Year's Eve',
# ...

# %%
df.loc[['Mamma Mia!','Four Christmases']]
# Out:
#                    Genre   Lead Studio  Audience score %  Profitability  \
# Film
# Mamma Mia!        Comedy     Universal                76       9.234454
# Mamma Mia!        Comedy     Universal                76       9.234454
# Four Christmases  Comedy  Warner Bros.                52       2.022925
#
#                   Rotten Tomatoes % Worldwide Gross  Year  Age  Good_Score
# Film
# Mamma Mia!                       53        $609.47   2008   16          23
# Mamma Mia!                       53        $609.47   2008   16          23
# Four Christmases                 26        $161.83   2008   16          26

# %%
df.iloc[4]
# Out:
# Genre                  Comedy
# Lead Studio               Fox
# Audience score %           72
# Profitability        6.267647
# Rotten Tomatoes %          28
# Worldwide Gross      $219.37
# Year                     2008
# Age                        16
# Good_Score                 44
# Name: What Happens in Vegas, dtype: object

# %%
df.reset_index (inplace=True)
df.head(3)
# Out:
#                                  Film    Genre            Lead Studio  \
# 0          Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                     Youth in Revolt   Comedy  The Weinstein Company
# 2  You Will Meet a Tall Dark Stranger   Comedy            Independent
#
#    Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year  \
# 0                70       1.747542                 64         $41.94   2008
# 1                52       1.090000                 68         $19.62   2010
# 2                35       1.211818                 43         $26.66   2010
#
#    Age  Good_Score
# 0   16           6
# 1   14         -16
# 2   14          -8
